# %%
import pandas as pd
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_1 = pd.read_csv('/Users/meetpatel/Desktop/pandas/dataset_1 - dataset_1.csv')
data_1
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# ...

# %%
data_2 = pd.read_csv('/Users/meetpatel/Desktop/pandas/dataset_2.xlsx - dataset_2.csv', index_col=0)
data_2
# Out:
#             instant   atemp   hum  windspeed  casual  registered  cnt
# Unnamed: 0
# 0                 1  0.2879  0.81     0.0000       3          13   16
# 1                 2  0.2727  0.80     0.0000       8          32   40
# 2                 3  0.2727  0.80     0.0000       5          27   32
# 3                 4  0.2879  0.75     0.0000       3          10   13
# 4                 5  0.2879  0.75     0.0000       0           1    1
# ...             ...     ...   ...        ...     ...         ...  ...
# 605             606  0.2121  0.93     0.1045       0          30   30
# 606             607  0.2121  0.93     0.1045       1          28   29
# 607             608  0.2121  0.93     0.1045       0          31   31
# 608             609  0.2727  0.80     0.0000       2          36   38
# 609             610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 7 columns]

# %%
merge_data = pd.merge(data_1,data_2, on='instant', how='inner')
merge_data
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
# ...

# %%
merge_data.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'casual',
#        'registered', 'cnt'],
#       dtype='object')

# %%
merge_data.drop(columns=['atemp'], inplace=True)

# %%
merge_data
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
# ...

# %%
merge_data.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
merge_data
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
# ...

# %%
data_3 = pd.read_csv('/Users/meetpatel/Desktop/pandas/dataset_3 - dataset_3.csv')
data_3
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620  29-01-2011       1   0     1   1    False        6           1
# 1        621  29-01-2011       1   0     1   2    False        6           1
# 2        622  29-01-2011       1   0     1   3    False        6           1
# 3        623  29-01-2011       1   0     1   4    False        6           1
# 4        624  29-01-2011       1   0     1   6    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %%
merge_1 = pd.concat([merge_data,data_3])
merge_1
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %%
merge_1.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'weathersit', 'temp', 'hum', 'windspeed', 'casual', 'registered', 'cnt',
#        'atemp'],
#       dtype='object')

# %%
merge_1.columns =['Index','Date','Season','Year','Month','Hour','Holiday','Weekday','Weathersit','Tempreature','Humdity','Windspeed','Casual','Registered','Count','Atemp']
merge_1
# Out:
#      Index        Date  Season  Year  Month  Hour  Holiday  Weekday  \
# 0        1  01-01-2011       1     0      1     0    False        6
# 1        2  01-01-2011       1     0      1     1    False        6
# 2        3  01-01-2011       1     0      1     2    False        6
# 3        4  01-01-2011       1     0      1     3    False        6
# 4        5  01-01-2011       1     0      1     4    False        6
# ..     ...         ...     ...   ...    ...   ...      ...      ...
# 385    615  28-01-2011       1     0      1    20    False        5
# 386    616  28-01-2011       1     0      1    21    False        5
# 387    617  28-01-2011       1     0      1    22    False        5
# 388    618  28-01-2011       1     0      1    23    False        5
# 389    619  29-01-2011       1     0      1     0    False        6
#
#      Weathersit  Tempreature  Humdity  Windspeed  Casual  Registered  Count  \
# ...

# %%
merge_1.drop('Atemp',axis=1,inplace=True)

# %%
merge_1
# Out:
#      Index        Date  Season  Year  Month  Hour  Holiday  Weekday  \
# 0        1  01-01-2011       1     0      1     0    False        6
# 1        2  01-01-2011       1     0      1     1    False        6
# 2        3  01-01-2011       1     0      1     2    False        6
# 3        4  01-01-2011       1     0      1     3    False        6
# 4        5  01-01-2011       1     0      1     4    False        6
# ..     ...         ...     ...   ...    ...   ...      ...      ...
# 385    615  28-01-2011       1     0      1    20    False        5
# 386    616  28-01-2011       1     0      1    21    False        5
# 387    617  28-01-2011       1     0      1    22    False        5
# 388    618  28-01-2011       1     0      1    23    False        5
# 389    619  29-01-2011       1     0      1     0    False        6
#
#      Weathersit  Tempreature  Humdity  Windspeed  Casual  Registered  Count
# ...

# %%
ds = pd.DataFrame(merge_1)
dimensions = ds.shape
print(f"Dimensions: {dimensions}")
# Out:
# Dimensions: (1000, 15)

# %%
data_types = ds.dtypes
data_types
# Out:
# Index            int64
# Date            object
# Season           int64
# Year             int64
# Month            int64
# Hour             int64
# Holiday           bool
# Weekday          int64
# Weathersit       int64
# Tempreature    float64
# Humdity        float64
# Windspeed      float64
# Casual           int64
# Registered       int64
# Count            int64
# dtype: object

# %%
uq=pd.DataFrame(merge_1)
unique_counts_df = uq.nunique()
unique_counts_df
# Out:
# Index          1000
# Date             45
# Season            1
# Year              1
# Month             2
# Hour             24
# Holiday           2
# Weekday           7
# Weathersit        4
# Tempreature      23
# Humdity          64
# Windspeed        20
# Casual           42
# Registered      186
# Count           191
# dtype: int64

# %%
merge_1.isnull().sum()
# Out:
# Index          0
# Date           0
# Season         0
# Year           0
# Month          0
# Hour           0
# Holiday        0
# Weekday        0
# Weathersit     0
# Tempreature    0
# Humdity        0
# Windspeed      0
# Casual         0
# Registered     0
# Count          0
# dtype: int64

# %%
summary_statistics = merge_1.describe()
summary_statistics
# Out:
#              Index  Season    Year        Month         Hour      Weekday  \
# count  1000.000000  1000.0  1000.0  1000.000000  1000.000000  1000.000000
# mean    500.500000     1.0     0.0     1.312000    11.753000     2.982000
# std     288.819436     0.0     0.0     0.463542     6.899101     2.091423
# min       1.000000     1.0     0.0     1.000000     0.000000     0.000000
# 25%     250.750000     1.0     0.0     1.000000     6.000000     1.000000
# 50%     500.500000     1.0     0.0     1.000000    12.000000     3.000000
# 75%     750.250000     1.0     0.0     2.000000    18.000000     5.000000
# max    1000.000000     1.0     0.0     2.000000    23.000000     6.000000
#
#         Weathersit  Tempreature      Humdity    Windspeed       Casual  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      1.480000     0.205900     0.582480     0.194931     4.921000
# std       0.651171     0.078977     0.187977     0.129126     7.643899
# ...

# %%
dff = pd.DataFrame(merge_1)
skewness_1 = dff[['Tempreature','Hour','Season','Year','Month','Weekday','Weathersit','Humdity','Windspeed','Casual','Registered','Count']].skew()
skewness_1
# Out:
# Tempreature    0.547997
# Hour          -0.063524
# Season         0.000000
# Year           0.000000
# Month          0.812772
# Weekday        0.021925
# Weathersit     1.044098
# Humdity        0.436893
# Windspeed      0.433675
# Casual         3.414105
# Registered     1.296723
# Count          1.137709
# dtype: float64

# %%
hg=  pd.DataFrame(merge_1)
hg['Tempreature'].hist(bins=20,  edgecolor='black')
plt.title('Histogram of  Tempreature')
plt.xlabel('Values')
plt.ylabel('Frequency')

new_ticks = [0.05 ,0.10, 0.15, 0.20, 0.25, 0.30, 0.35, 0.40]  
plt.xticks(new_ticks)
plt.show()

# %%
ws=  pd.DataFrame(merge_1)
ws['Windspeed'].hist(bins=20,  edgecolor='black')
plt.title('Histogram of  Windspeed')
plt.xlabel('Values')
plt.ylabel('Frequency')

new_ticks = [0.05 ,0.10, 0.15, 0.20, 0.25, 0.30, 0.35, 0.40]  
plt.xticks(new_ticks)
plt.show()

# %%
hd=  pd.DataFrame(merge_1)
hd['Humdity'].hist(bins=20,  edgecolor='black')
plt.title('Histogram of  Humdity')
plt.xlabel('Values')
plt.ylabel('Frequency')

new_ticks = [0.10, 0.20 ,0.30,0.40,0.50,0.60,0.70,0.80,0.90]  
plt.xticks(new_ticks)
plt.show()

# %%
wt=  pd.DataFrame(merge_1)
wt['Weathersit'].hist(bins=20,  edgecolor='black')
plt.title('Histogram of  Weathersit')
plt.xlabel('Values')
plt.ylabel('Frequency')

new_ticks = [0 ,1,2,3,4]  
plt.xticks(new_ticks)
plt.show()

# %%
merge_1
# Out:
#      Index        Date  Season  Year  Month  Hour  Holiday  Weekday  \
# 0        1  01-01-2011       1     0      1     0    False        6
# 1        2  01-01-2011       1     0      1     1    False        6
# 2        3  01-01-2011       1     0      1     2    False        6
# 3        4  01-01-2011       1     0      1     3    False        6
# 4        5  01-01-2011       1     0      1     4    False        6
# ..     ...         ...     ...   ...    ...   ...      ...      ...
# 385    615  28-01-2011       1     0      1    20    False        5
# 386    616  28-01-2011       1     0      1    21    False        5
# 387    617  28-01-2011       1     0      1    22    False        5
# 388    618  28-01-2011       1     0      1    23    False        5
# 389    619  29-01-2011       1     0      1     0    False        6
#
#      Weathersit  Tempreature  Humdity  Windspeed  Casual  Registered  Count
# ...

# %%
merge_1.to_csv('acquired_data.csv', index=False)
merge_1
# Out:
#      Index        Date  Season  Year  Month  Hour  Holiday  Weekday  \
# 0        1  01-01-2011       1     0      1     0    False        6
# 1        2  01-01-2011       1     0      1     1    False        6
# 2        3  01-01-2011       1     0      1     2    False        6
# 3        4  01-01-2011       1     0      1     3    False        6
# 4        5  01-01-2011       1     0      1     4    False        6
# ..     ...         ...     ...   ...    ...   ...      ...      ...
# 385    615  28-01-2011       1     0      1    20    False        5
# 386    616  28-01-2011       1     0      1    21    False        5
# 387    617  28-01-2011       1     0      1    22    False        5
# 388    618  28-01-2011       1     0      1    23    False        5
# 389    619  29-01-2011       1     0      1     0    False        6
#
#      Weathersit  Tempreature  Humdity  Windspeed  Casual  Registered  Count
# ...
